# %% [markdown]
# # In this notebook we will perfrom EDA for the data

# %% [markdown]
# ## At first we will install all the dependencies

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\youca\anaconda3\envs\ml\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
! pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\youca\anaconda3\envs\ml\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\youca\anaconda3\envs\ml\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\youca\anaconda3\envs\ml\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
! pip install pathlib
# Out:
# Requirement already satisfied: pathlib in c:\users\youca\anaconda3\envs\ml\lib\site-packages (1.0.1)

# %% [markdown]
# - **Importing all the Libraries**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# - **Creating path object to find actual path**

# %%
directory = Path(__name__).parent.absolute()
directory = directory.parent

# %% [markdown]
# - **Load the Dataframe**

# %%
df = pd.read_csv(str(directory) + "/data/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2028  4452-ROHMO  Female              0      No         No      15
# 5748  4686-UXDML  Female              0      No         No      21
# 4140  2748-MYRVK  Female              0      No         No      63
# 5109  7113-HIPFI    Male              0     Yes        Yes      66
# 5106  8878-RYUKI  Female              0      No         No      52
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 2028          Yes            No              No  No internet service  ...
# 5748          Yes           Yes     Fiber optic                   No  ...
# 4140          Yes           Yes     Fiber optic                   No  ...
# 5109          Yes            No             DSL                  Yes  ...
# 5106          Yes            No             DSL                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 2028  No internet service  No internet service  No internet service
# 5748                   No                   No                  Yes
# 4140                   No                   No                  Yes
# 5109                  Yes                  Yes                   No
# 5106                  Yes                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 2028  No internet service        Two year               No
# 5748                  Yes  Month-to-month              Yes
# 4140                  Yes        One year               No
# 5109                   No        Two year               No
# 5106                  Yes  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 2028               Mailed check          19.60         331.6    No
# 5748    Credit card (automatic)          99.85       1992.55    No
# 4140  Bank transfer (automatic)          99.90          6137   Yes
# 5109               Mailed check          65.85       4097.05    No
# 5106           Electronic check          59.45        3043.7    No
#
# [5 rows x 21 columns]

# %% [markdown]
# ## **Univariate Analysis (individual columns)**

# %% [markdown]
# ### **Making a count plot for `Churn`**

# %%
sns.countplot(x='Churn', data=df)
plt.title('Churn Distribution')
plt.show()

# %% [markdown]
# ### **Making a count plot for `Gender`**

# %%
sns.countplot(data=df, x='gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `SeniorCitizen`**

# %%
sns.countplot(data=df, x='SeniorCitizen')
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `Partner`**

# %%
sns.countplot(data=df, x='Partner')
# Out:
# <Axes: xlabel='Partner', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `Dependents`**

# %%
sns.countplot(data=df, x='Dependents')
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `PhoneService`**

# %%
sns.countplot(data=df, x='PhoneService')
# Out:
# <Axes: xlabel='PhoneService', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `MultipleLines`**

# %%
sns.countplot(data=df, x='MultipleLines')
# Out:
# <Axes: xlabel='MultipleLines', ylabel='count'>

# %% [markdown]
# - **This column needs some improvement**
#       - **We will replace all the `no internet service` and `no phone service` to `no`**

# %%
df['MultipleLines'] = df['MultipleLines'].replace({
    'No phone service': 'No'
})

# %% [markdown]
# - **Now Let us check the result**

# %%
sns.countplot(data=df, x='MultipleLines')
# Out:
# <Axes: xlabel='MultipleLines', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `InternetService`**

# %%
sns.countplot(data=df, x='InternetService')
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `OnlineSecurity`**

# %%
sns.countplot(data=df, x='OnlineSecurity')
# Out:
# <Axes: xlabel='OnlineSecurity', ylabel='count'>

# %% [markdown]
# - **This column needs some improvement**
#       - **We will replace all the `no internet service` and `no phone service` to `no`**

# %%
df['OnlineSecurity'] = df['OnlineSecurity'].replace({
    'No internet service': 'No'
})

# %% [markdown]
# - **Now Let us check the result**

# %%
sns.countplot(data=df, x='OnlineSecurity')
# Out:
# <Axes: xlabel='OnlineSecurity', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `OnlineBackup`**

# %%
sns.countplot(data=df, x='OnlineBackup')
# Out:
# <Axes: xlabel='OnlineBackup', ylabel='count'>

# %% [markdown]
# - **This column needs some improvement**
#       - **We will replace all the `no internet service` and `no phone service` to `no`**

# %%
df['OnlineBackup'] = df['OnlineBackup'].replace({
    'No internet service': 'No'
})

# %% [markdown]
# - **Now Let us check the result**

# %%
sns.countplot(data=df, x='OnlineBackup')
# Out:
# <Axes: xlabel='OnlineBackup', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `DeviceProtection`**

# %%
sns.countplot(data=df, x='DeviceProtection')
# Out:
# <Axes: xlabel='DeviceProtection', ylabel='count'>

# %% [markdown]
# - **This column needs some improvement**
#       - **We will replace all the `no internet service` and `no phone service` to `no`**

# %%
df['DeviceProtection'] = df['DeviceProtection'].replace({
    'No internet service': 'No'
})

# %% [markdown]
# - **Now Let us check the result**

# %%
sns.countplot(data=df, x='DeviceProtection')
# Out:
# <Axes: xlabel='DeviceProtection', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `TechSupport`**

# %%
sns.countplot(data=df, x='TechSupport')
# Out:
# <Axes: xlabel='TechSupport', ylabel='count'>

# %% [markdown]
# - **This column needs some improvement**
#       - **We will replace all the `no internet service` and `no phone service` to `no`**

# %%
df['TechSupport'] = df['TechSupport'].replace({
    'No internet service': 'No'
})

# %% [markdown]
# - **Now Let us check the result**

# %%
sns.countplot(data=df, x='TechSupport')
# Out:
# <Axes: xlabel='TechSupport', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `StreamingTV`**

# %%
sns.countplot(data=df, x='StreamingTV')
# Out:
# <Axes: xlabel='StreamingTV', ylabel='count'>

# %% [markdown]
# - **This column needs some improvement**
#       - **We will replace all the `no internet service` and `no phone service` to `no`**

# %%
df['StreamingTV'] = df['StreamingTV'].replace({
    'No internet service': 'No'
})

# %% [markdown]
# - **Now Let us check the result**

# %%
sns.countplot(data=df, x='StreamingTV')
# Out:
# <Axes: xlabel='StreamingTV', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `StreamingMovies`**

# %%
sns.countplot(data=df, x='StreamingMovies')
# Out:
# <Axes: xlabel='StreamingMovies', ylabel='count'>

# %% [markdown]
# - **This column needs some improvement**
#       - **We will replace all the `no internet service` and `no phone service` to `no`**

# %%
df['StreamingMovies'] = df['StreamingMovies'].replace({
    'No internet service': 'No'
})

# %% [markdown]
# - **Now Let us check the result**

# %%
sns.countplot(data=df, x='StreamingMovies')
# Out:
# <Axes: xlabel='StreamingMovies', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `Contract`**

# %%
sns.countplot(data=df, x='Contract')
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `PaperlessBilling`**

# %%
sns.countplot(data=df, x='PaperlessBilling')
# Out:
# <Axes: xlabel='PaperlessBilling', ylabel='count'>

# %% [markdown]
# ### **Making a count plot for `PaymentMethod`**

# %%
plt.figure(figsize=(10, 10))
sns.countplot(data=df, x='PaymentMethod')
plt.show()

# %% [markdown]
# ## **Bivariate Analysis (relationships between two columns)**

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5532  8174-LNWMW  Female              0      No         No      31
# 4149  6559-ILWKJ    Male              0     Yes         No      71
# 68    3170-NMYVV  Female              0     Yes        Yes      50
# 6829  8148-WOCMK    Male              0     Yes        Yes       8
# 3572  1730-ZMAME  Female              1      No         No      32
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 5532          Yes            No              No             No  ...
# 4149           No            No             DSL             No  ...
# 68            Yes            No              No             No  ...
# 6829          Yes            No              No             No  ...
# 3572          Yes            No     Fiber optic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 5532               No          No          No              No        Two year
# 4149               No          No         Yes             Yes        Two year
# 68                 No          No          No              No        Two year
# 6829               No          No          No              No        Two year
# 3572               No          No          No             Yes  Month-to-month
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 5532               No    Credit card (automatic)          20.90        689.35
# 4149               No           Electronic check          49.35       3515.25
# 68                 No  Bank transfer (automatic)          20.15         930.9
# 6829               No    Credit card (automatic)          19.60           125
# 3572              Yes           Electronic check          79.50          2665
#
#      Churn
# 5532    No
# 4149   Yes
# 68      No
# 6829    No
# 3572    No
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB
